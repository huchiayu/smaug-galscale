# %%
from read_PD import plot_PD
from read_PD import compare_PDF
from read_PnPD import plot_PnPD
from plotEquilPD import plotEquilPD

# %% [markdown]
# # Phase diagram
# ## Cooling only
# No Gadget run because Gadget crashed at ~ 90 Myr

# %%
plot_PD(code='enzo', fb=False, sf=False)
# Out:
# read_PD.py:118: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(data), extent=extent, interpolation=None, cmap='viridis', origin='lower')

# %%
plot_PD(code='ramses', fb=False, sf=False)

# %% [markdown]
# ## Cooling + star formation

# %%
plot_PD(code='enzo', fb=False, sf=True)

# %%
plot_PD(code='ramses', fb=False, sf=True)

# %%
plot_PD(code='gadget', fb=False, sf=True)

# %% [markdown]
# ## Cooling + star formation + feedback
# No Enzo run yet

# %%
plot_PD(code='ramses', fb=True)

# %%
plot_PD(code='gadget', fb=True)

# %% [markdown]
# # Pressure vs. density
# ## Cooling only

# %%
plot_PnPD(code='enzo', fb=False, sf=False)
# Out:
# read_PnPD.py:55: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(data), extent=extent, interpolation=None, cmap='viridis', origin='lower')

# %%
plot_PnPD(code='ramses', fb=False, sf=False)

# %% [markdown]
# ## Cooling + star formation

# %%
plot_PnPD(code='enzo', fb=False, sf=True)

# %%
plot_PnPD(code='ramses', fb=False, sf=True)

# %%
plot_PnPD(code='gadget', fb=False, sf=True)

# %% [markdown]
# ## Cooling + star formation + feedback

# %%
plot_PnPD(code='ramses', fb=True)

# %%
plot_PnPD(code='gadget', fb=True)

# %% [markdown]
# # PDF of density & temperature
# ## Cooling + star formation

# %%
compare_PDF('0000', fb=False, sf=True)
# Out:
# gadget ['gadget', 'ramses', 'enzo']
# ramses ['gadget', 'ramses', 'enzo']
# /Users/chu/anaconda/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# enzo ['gadget', 'ramses', 'enzo']

# %%
compare_PDF('0500', fb=False, sf=True)
# Out:
# gadget ['gadget', 'ramses', 'enzo']
# ramses ['gadget', 'ramses', 'enzo']
# enzo ['gadget', 'ramses', 'enzo']

# %% [markdown]
# ## Cooling + star formation + feedback

# %%
compare_PDF('1000', fb=True)
# Out:
# gadget ['gadget', 'ramses']
# ramses ['gadget', 'ramses']
